# %%
import cv2
import csv
import os

# Path to the folder containing the frames
frames_folder = r'E:\Major_project_main\Main\test_data\MVl_3208_1'
# Path to the CSV file
csv_file = os.path.join(frames_folder,"ball_info.csv")

# Temporary folder to save the images
temp = "temp"
temp_folder = os.path.join(frames_folder,temp)
# Output video file name
output_video = os.path.join(frames_folder,"output_video.mp4")

# Create the temporary folder if it doesn't exist
os.makedirs(temp_folder, exist_ok=True)

# Read the CSV file
with open(csv_file, 'r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  # Skip the header row if present

    # Iterate over each row in the CSV file
    for row in csv_reader:
        frame_name = row[0]
        x_center = int(float(row[1]))
        y_center = int(float(row[2]))
        radius =int(float(row[3]))

        # Read the frame image
        frame_path = os.path.join(frames_folder,frame_name)
        # print(frame_path,x_center,y_center )
        frame = cv2.imread(frame_path)

        # Draw the circle on the frame
        cv2.circle(frame, (x_center, y_center), radius, (0, 255, 0), -1)

        # Save the modified frame image in the temporary folder
        output_path = os.path.join(temp_folder, frame_name)
        cv2.imwrite(output_path, frame)

# Convert the images in the temporary folder to a video
frame_rate = 10 # Adjust the frame rate as needed

# Get the dimensions of the first frame
first_frame_path = os.path.join(temp_folder, os.listdir(temp_folder)[0])
first_frame = cv2.imread(first_frame_path)
frame_width, frame_height = first_frame.shape[1], first_frame.shape[0]

# Initialize the video writer
output = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), frame_rate, (frame_width, frame_height))

# Iterate over the images in the temporary folder to write them to the output video
image_files = sorted(os.listdir(temp_folder))
for image_file in image_files:
    image_path = os.path.join(temp_folder, image_file)
    frame = cv2.imread(image_path)
    output.write(frame)

# Release the video writer
output.release()

# Clean up: Delete the temporary folder and its contents
for image_file in image_files:
    image_path = os.path.join(temp_folder, image_file)
    os.remove(image_path)
os.rmdir(temp_folder)

# %%
import cv2
import csv
import os

# Path to the folder containing the frames
frames_folder = r'E:\Major_project_main\Main\test_data\MVl_3208_1'
# Path to the CSV file
csv_file = os.path.join(frames_folder,"ball_info.csv")

# Temporary folder to save the images
temp = "temp"
temp_folder = os.path.join(frames_folder,temp)
# Output video file name
output_video = os.path.join(frames_folder,"output_video1.mp4")

# Create the temporary folder if it doesn't exist
os.makedirs(temp_folder, exist_ok=True)
# Read the CSV file
with open(csv_file, 'r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  # Skip the header row if present

    prev_frame = None  # Previous frame to keep track of trajectory

    # Iterate over each row in the CSV file
    for row in csv_reader:
        frame_name = row[0]
        x_center = int(float(row[1]))
        y_center = int(float(row[2]))
        radius = int(float(row[3]))

        # Read the frame image
        frame_path = os.path.join(frames_folder, frame_name)
        frame = cv2.imread(frame_path)

        # Draw the circle on the frame
        cv2.circle(frame, (x_center, y_center), radius, (0, 255, 0), -1)

        if prev_frame is not None:
            # Draw a line connecting the centers of the current and previous frames
            cv2.line(frame, (x_center, y_center), prev_frame, (0, 255, 0), 2)

        # Save the modified frame image in the temporary folder
        output_path = os.path.join(temp_folder, frame_name)
        cv2.imwrite(output_path, frame)

        prev_frame = (x_center, y_center)

    # Save the last frame with the whole trajectory as an image
    last_frame_path = os.path.join(temp_folder, frame_name)
    cv2.imwrite(last_frame_path, frame)

# Convert the images in the temporary folder to a video
frame_rate = 10  # Adjust the frame rate as needed

# Get the dimensions of the first frame
first_frame_path = os.path.join(temp_folder, os.listdir(temp_folder)[0])
first_frame = cv2.imread(first_frame_path)
frame_width, frame_height = first_frame.shape[1], first_frame.shape[0]

# Initialize the video writer
output = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), frame_rate, (frame_width, frame_height))

# Iterate over the images in the temporary folder to write them to the output video
image_files = sorted(os.listdir(temp_folder))
for image_file in image_files:
    image_path = os.path.join(temp_folder, image_file)
    frame = cv2.imread(image_path)
    output.write(frame)

# Release the video writer
output.release()

# %%
import cv2
import csv
import os

# Path to the folder containing the frames
frames_folder = r'E:\Major_project_main\Main\test_data\MVl_3208_1'
# Path to the CSV file
csv_file = os.path.join(frames_folder,"ball_info.csv")

# Temporary folder to save the images
temp = "temp"
temp_folder = os.path.join(frames_folder,temp)
# Output video file name
output_video = os.path.join(frames_folder,"output_video1.mp4")

# Create the temporary folder if it doesn't exist
os.makedirs(temp_folder, exist_ok=True)
# Read the CSV file
with open(csv_file, 'r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  # Skip the header row if present


    # Iterate over each row in the CSV file
    prev_frame_circles = [] 
    for row in csv_reader:
        frame_name = row[0]
        x_center = int(float(row[1]))
        y_center = int(float(row[2]))
        radius = int(float(row[3]))

        # Read the frame image
        frame_path = os.path.join(frames_folder, frame_name)
        frame = cv2.imread(frame_path)

        
        # Draw the circle for the current frame
        cv2.circle(frame, (x_center, y_center), radius, (0, 255, 0), -1)

        # Draw the circles from previous frames
        for circle in prev_frame_circles:
            prev_x, prev_y, prev_radius = circle
            print(circle)
            cv2.circle(frame, (prev_x, prev_y), prev_radius, (0, 255, 0), -1)
        # Add current circle to the list of previous frame circles
        prev_frame_circles.append([x_center, y_center, radius])

        # Save the modified frame image in the temporary folder
        output_path = os.path.join(temp_folder, frame_name)
        cv2.imwrite(output_path, frame)



    # Save the last frame with the whole trajectory as an image
    last_frame_path = os.path.join(frames_folder, f"Out_{frame_name}")
    cv2.imwrite(last_frame_path, frame)

# Convert the images in the temporary folder to a video
frame_rate = 10  # Adjust the frame rate as needed

# Get the dimensions of the first frame
first_frame_path = os.path.join(temp_folder, os.listdir(temp_folder)[0])
first_frame = cv2.imread(first_frame_path)
frame_width, frame_height = first_frame.shape[1], first_frame.shape[0]

# Initialize the video writer
output = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), frame_rate, (frame_width, frame_height))

# Iterate over the images in the temporary folder to write them to the output video
image_files = sorted(os.listdir(temp_folder))
for image_file in image_files:
    image_path = os.path.join(temp_folder, image_file)
    frame = cv2.imread(image_path)
    output.write(frame)

# Release the video writer
output.release()

for image_file in image_files:
    image_path = os.path.join(temp_folder, image_file)
    os.remove(image_path)
os.rmdir(temp_folder)
# Out:
# [170, 47, 32]
# [170, 47, 32]
# [336, 86, 23]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [911, 148, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [911, 148, 3]
# [911, 148, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [911, 148, 3]
# [911, 148, 3]
# [909, 144, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [911, 148, 3]
# [911, 148, 3]
# [909, 144, 3]
# [908, 141, 3]
# [170, 47, 32]
# [336, 86, 23]
# [336, 86, 23]
# [452, 117, 19]
# [539, 149, 17]
# [604, 180, 14]
# [655, 213, 14]
# [655, 213, 14]
# [697, 242, 12]
# [730, 273, 10]
# [760, 303, 9]
# [785, 334, 9]
# [785, 334, 9]
# [806, 363, 8]
# [823, 391, 8]
# [839, 346, 7]
# [853, 308, 7]
# [853, 308, 7]
# [868, 277, 6]
# [878, 252, 6]
# [889, 231, 6]
# [902, 217, 7]
# [902, 217, 7]
# [910, 206, 6]
# [922, 202, 8]
# [929, 196, 6]
# [929, 197, 6]
# [929, 197, 6]
# [926, 203, 5]
# [924, 212, 5]
# [922, 222, 5]
# [919, 202, 5]
# [919, 202, 5]
# [916, 184, 2]
# [915, 169, 3]
# [914, 158, 3]
# [911, 148, 3]
# [911, 148, 3]
# [909, 144, 3]
# [908, 141, 3]
# [906, 141, 3]
